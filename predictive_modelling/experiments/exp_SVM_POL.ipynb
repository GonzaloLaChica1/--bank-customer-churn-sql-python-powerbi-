# %% [markdown]
# <h2><strong>Support Vector-Pol Kernel</strong></h2>
#
# **Load data and libraries**

# %%
import warnings
warnings.filterwarnings("ignore")
import joblib
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from evaluation_script import evaluate_model

# %%
#LOAD PROCESSED DATA 

data= joblib.load('../processed_data/dataset_bundle.pkl')
X_train= data['X_train']
y_train=data['Y_train']
X_test=data['X_test']
y_test=data['Y_test']

# %% [markdown]
# **Find the best Parameters**

# %%
#declare parameters

param_grid = {
    "C": [0.5,1,10,50,100],
    "gamma": [0.1,0.01,0.001],
    "kernel": ['poly'],
    "degree": [2,3]
}

# %%
#generate search space
SVM_Grid = GridSearchCV(
    SVC(class_weight="balanced"),
    param_grid,
    cv=3,
    refit=True,
    scoring="f1",
    n_jobs=-1,
    verbose=1
)

# %% [markdown]
# FIT BEST MODEL ON TRAINING

# %%
SVM_Grid.fit(X_train, y_train)
best_model = SVM_Grid.best_estimator_


results = evaluate_model(best_model, X_test, y_test)
results
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# {'Recall_Churn': 0.6711229946524064,
#  'Precision_Churn': 0.49604743083003955,
#  'F1_Churn': 0.5704545454545454,
#  'ROC_AUC': np.float64(0.8295166775197163)}
